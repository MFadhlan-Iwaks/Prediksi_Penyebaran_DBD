# %% [markdown]
# # Eksplorasi Data DBD Jawa Barat
#
# Notebook awal untuk membaca dataset estimasi harian dan ringkasan tahunan DBD Jawa Barat 2016-2024.

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
dataset_path = project_root / 'data' / 'processed' / 'dataset_harian_estimasi_dbd_jabar_2016_2024_agregat.csv'

df = pd.read_csv(dataset_path)
df.head()
